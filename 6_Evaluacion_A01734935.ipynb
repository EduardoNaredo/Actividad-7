# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv("cuentas_credicel.csv", encoding = 'latin')
df
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_27772\628335023.py:1: DtypeWarning: Columns (26,31,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("cuentas_credicel.csv", encoding = 'latin')
#        folio       tag  folio_solicitud             fecha     marca  \
# 0          3  HDNAWQ3A               30  12/11/2021 19:00       ZTE
# 1          4  M418YNR4               33  12/11/2021 19:15  MOTOROLA
# 2          5  SZ7V3NZT               37  13/11/2021 14:13       ZTE
# 3          6  9I08UIQZ               38  13/11/2021 15:45       ZTE
# 4          7  JMF4LKYU               44  13/11/2021 16:10  MOTOROLA
# ...      ...       ...              ...               ...       ...
# 22730  22967  92KQVRIX            96502  18/04/2023 18:45  Motorola
# 22731  22968  NWB2EA8J            96479  18/04/2023 18:46  Motorola
# 22732  22969  VDTRJ2W6            96442  18/04/2023 18:47   Samsung
# ...

# %%
df2=df.drop(['folio', 'folio_solicitud', 'Unnamed: 33', 'Unnamed: 34', "Unnamed: 35", "Unnamed: 36"], axis=1)
df2
# Out:
#             tag             fecha     marca                        modelo  \
# 0      HDNAWQ3A  12/11/2021 19:00       ZTE            Blade A3 2020 RO B
# 1      M418YNR4  12/11/2021 19:15  MOTOROLA  LTE XT2097-12 E7I POWER Azul
# 2      SZ7V3NZT  13/11/2021 14:13       ZTE            BLADE A3 2020 Gris
# 3      9I08UIQZ  13/11/2021 15:45       ZTE            BLADE A3 2020 Gris
# 4      JMF4LKYU  13/11/2021 16:10  MOTOROLA                         G10 B
# ...         ...               ...       ...                           ...
# 22730  92KQVRIX  18/04/2023 18:45  Motorola                      Moto E13
# 22731  NWB2EA8J  18/04/2023 18:46  Motorola                     Moto E22i
# 22732  VDTRJ2W6  18/04/2023 18:47   Samsung                           A13
# 22733  PETLF56C  18/04/2023 18:49   Samsung                        A53 5G
# 22734  2CI4N2WS  18/04/2023 18:49   Samsung                        A22 5G
#
#       plazo  precio  enganche  descuento  semana  monto_financiado  \
# ...

# %%
df3 = df.iloc[::4]
df3
# Out:
#        folio       tag  folio_solicitud             fecha     marca  \
# 0          3  HDNAWQ3A               30  12/11/2021 19:00       ZTE
# 4          7  JMF4LKYU               44  13/11/2021 16:10  MOTOROLA
# 8         11  5SDZN7O1               59  14/11/2021 13:34     KODAK
# 12        15  BFXA3OX9               77  15/11/2021 12:10  MOTOROLA
# 16        19  X53IWV9M               83  16/11/2021 13:35   ALCATEL
# ...      ...       ...              ...               ...       ...
# 22716  22953  AN6FJ9K0            59804  18/04/2023 16:43   Alcatel
# 22720  22957  WI1NMWI1            96476  18/04/2023 17:04  MOTOROLA
# 22724  22961  RTBMD1Z2            96484  18/04/2023 17:15  Motorola
# 22728  22965  X4AXNZBG            96444  18/04/2023 17:33  Motorola
# 22732  22969  VDTRJ2W6            96442  18/04/2023 18:47   Samsung
#
#                            modelo plazo   precio  enganche  descuento  semana  \
# ...

# %%
marcas_permitidas = ["ALCATEL", "MOTOROLA", "NOKIA", "ZTE", "SAMSUNG"]
marcas = df["marca"].isin(marcas_permitidas)
registros_filtrados = df["marca"].unique
registros_filtrados
# Out:
# <bound method Series.unique of 0             ZTE
# 1        MOTOROLA
# 2             ZTE
# 3             ZTE
# 4        MOTOROLA
#            ...
# 22730    Motorola
# 22731    Motorola
# 22732     Samsung
# 22733     Samsung
# 22734     Samsung
# Name: marca, Length: 22735, dtype: object>

# %%
#
df(float)
enganche_permitido = df[(df["enganche">500]) & (df["enganche"<2001])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 2
#       1 #
# ----> 2 df(float)
#       3 enganche_permitido = df[(df["enganche">500]) & (df["enganche"<2001])]
#
# TypeError: 'DataFrame' object is not callable

# %%
#Todos los registros cuya categoria en riesgo no sea cancelado ni fraude
riesgo_nopermitido = ["Cancelado", "Fraude"]
riesgo = [~df["riesgo"].isin(riesgo_nopermitido)]

# %%
#Todos los registros que la fecha sea posterior a 15/11/2021
fecha_registro = df[df["fecha"]>"15/11/2021"]
fecha_registro
# Out:
#        folio       tag  folio_solicitud             fecha     marca  \
# 12        15  BFXA3OX9               77  15/11/2021 12:10  MOTOROLA
# 13        16  6OAI6KXK               78  15/11/2021 12:39       NYX
# 14        17  3UE093E9               80  15/11/2021 15:02       ZTE
# 15        18  0H6OS2SU               81  15/11/2021 16:53  MOTOROLA
# 16        19  X53IWV9M               83  16/11/2021 13:35   ALCATEL
# ...      ...       ...              ...               ...       ...
# 22730  22967  92KQVRIX            96502  18/04/2023 18:45  Motorola
# 22731  22968  NWB2EA8J            96479  18/04/2023 18:46  Motorola
# 22732  22969  VDTRJ2W6            96442  18/04/2023 18:47   Samsung
# 22733  22970  PETLF56C            96536  18/04/2023 18:49   Samsung
# 22734  22971  2CI4N2WS            96534  18/04/2023 18:49   Samsung
#
#                              modelo plazo  precio  enganche  descuento  ...  \
# ...

# %%
df2.to_csv("df2_filtros.csv", index=False, encoding="utf-8")

# %%
dfNan=df2.copy()

# %%
valores_nulos=dfNan.isnull().sum()
valores_nulos
# Out:
# tag                      0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                 13
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago     3356
# fecha_pago_proximo    3356
# status_cuenta         4197
# puntos                3595
# riesgo                2473
# porc_enganche         2473
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
dfNan['fecha_ultimo_pago'] = dfNan["fecha_ultimo_pago"].fillna("01-01-2030 00:00:00")
dfNan['fecha_pago_proximo'] = dfNan["fecha_pago_proximo"].fillna("01-01-2030 00:00:00")
dfNan
# Out:
#             tag             fecha     marca                        modelo  \
# 0      HDNAWQ3A  12/11/2021 19:00       ZTE            Blade A3 2020 RO B
# 1      M418YNR4  12/11/2021 19:15  MOTOROLA  LTE XT2097-12 E7I POWER Azul
# 2      SZ7V3NZT  13/11/2021 14:13       ZTE            BLADE A3 2020 Gris
# 3      9I08UIQZ  13/11/2021 15:45       ZTE            BLADE A3 2020 Gris
# 4      JMF4LKYU  13/11/2021 16:10  MOTOROLA                         G10 B
# ...         ...               ...       ...                           ...
# 22730  92KQVRIX  18/04/2023 18:45  Motorola                      Moto E13
# 22731  NWB2EA8J  18/04/2023 18:46  Motorola                     Moto E22i
# 22732  VDTRJ2W6  18/04/2023 18:47   Samsung                           A13
# 22733  PETLF56C  18/04/2023 18:49   Samsung                        A53 5G
# 22734  2CI4N2WS  18/04/2023 18:49   Samsung                        A22 5G
#
#       plazo  precio  enganche  descuento  semana  monto_financiado  \
# ...

# %%
valores_nulos=dfNan.isnull().sum()
valores_nulos
# Out:
# tag                      0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                 13
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago        0
# fecha_pago_proximo       0
# status_cuenta         4197
# puntos                3595
# riesgo                2473
# porc_enganche         2473
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
#Tipo String
dfNan['empresa'] = dfNan["empresa"].fillna('Sin registro')
dfNan['status_cuenta'] = dfNan["status_cuenta"].fillna('Sin registro')
dfNan['riesgo'] = dfNan["riesgo"].fillna('Sin registro')
dfNan
# Out:
#             tag             fecha     marca                        modelo  \
# 0      HDNAWQ3A  12/11/2021 19:00       ZTE            Blade A3 2020 RO B
# 1      M418YNR4  12/11/2021 19:15  MOTOROLA  LTE XT2097-12 E7I POWER Azul
# 2      SZ7V3NZT  13/11/2021 14:13       ZTE            BLADE A3 2020 Gris
# 3      9I08UIQZ  13/11/2021 15:45       ZTE            BLADE A3 2020 Gris
# 4      JMF4LKYU  13/11/2021 16:10  MOTOROLA                         G10 B
# ...         ...               ...       ...                           ...
# 22730  92KQVRIX  18/04/2023 18:45  Motorola                      Moto E13
# 22731  NWB2EA8J  18/04/2023 18:46  Motorola                     Moto E22i
# 22732  VDTRJ2W6  18/04/2023 18:47   Samsung                           A13
# 22733  PETLF56C  18/04/2023 18:49   Samsung                        A53 5G
# 22734  2CI4N2WS  18/04/2023 18:49   Samsung                        A22 5G
#
#       plazo  precio  enganche  descuento  semana  monto_financiado  \
# ...

# %%
valores_nulos=dfNan.isnull().sum()
valores_nulos
# Out:
# tag                      0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                  0
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago        0
# fecha_pago_proximo       0
# status_cuenta            0
# puntos                3595
# riesgo                   0
# porc_enganche         2473
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
#Tipo Numerico
dfNan['puntos'] = dfNan["puntos"].fillna(round(dfNan["puntos"].mean()))


dfNan
# Out:
#             tag             fecha     marca                        modelo  \
# 0      HDNAWQ3A  12/11/2021 19:00       ZTE            Blade A3 2020 RO B
# 1      M418YNR4  12/11/2021 19:15  MOTOROLA  LTE XT2097-12 E7I POWER Azul
# 2      SZ7V3NZT  13/11/2021 14:13       ZTE            BLADE A3 2020 Gris
# 3      9I08UIQZ  13/11/2021 15:45       ZTE            BLADE A3 2020 Gris
# 4      JMF4LKYU  13/11/2021 16:10  MOTOROLA                         G10 B
# ...         ...               ...       ...                           ...
# 22730  92KQVRIX  18/04/2023 18:45  Motorola                      Moto E13
# 22731  NWB2EA8J  18/04/2023 18:46  Motorola                     Moto E22i
# 22732  VDTRJ2W6  18/04/2023 18:47   Samsung                           A13
# 22733  PETLF56C  18/04/2023 18:49   Samsung                        A53 5G
# 22734  2CI4N2WS  18/04/2023 18:49   Samsung                        A22 5G
#
#       plazo  precio  enganche  descuento  semana  monto_financiado  \
# ...

# %%
valores_nulos=dfNan.isnull().sum()
valores_nulos
# Out:
# tag                      0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                  0
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago        0
# fecha_pago_proximo       0
# status_cuenta            0
# puntos                   0
# riesgo                   0
# porc_enganche         2473
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
df2.to_csv("df2_valoresnulos.csv", index=False, encoding="utf-8")

# %%
for column in dfNan.select_dtypes(include=["float64","int64"]).columns:
    plt.figure(figsize=(6,3))
    dfNan.boxplot(column=[column])
    plt.title(f"{column} - Después de reemplazar outliers")
    plt.show()

# %%
dfNan.to_csv("df2_valoresnulos.csv", index=False, encoding="utf-8")
